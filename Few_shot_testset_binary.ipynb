# %%
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# %%
dirpath = Path("PreprocessedData")
dataset = "jester_tmp"
filepath = dirpath / dataset / "Jester_test_300.csv"
df = pd.read_csv(filepath)
df.shape
# Out:
# (14930, 5)

# %%
def get_columns(dataset):
    if dataset == "go_emo":
        return sorted([
            'admiration','amusement', 'anger', 'annoyance', 'approval', 'caring',
            'confusion', 'curiosity', 'desire', 'disappointment', 'disapproval',
            'disgust', 'embarrassment', 'excitement', 'fear', 'gratitude', 'grief',
            'joy', 'love', 'nervousness', 'optimism', 'pride', 'realization', 'relief',
            'remorse', 'sadness', 'surprise', 'neutral'
        ]), "rater_id", "text"
    if dataset == "unhealthy":
        return sorted([
            "antagonize", "condescending" , "dismissive", "generalisation",
            "generalisation_unfair", "healthy", "hostile", "sarcastic"
        ]), "_worker_id", "comment"
    if dataset == "docanno":
        return sorted([
            'inspiring', 'interesting', 'offensive_to_someone', 'negative',
            'offensive_to_me', 'political', 'positive', 'sadness', 'calm',
            'fear', 'compassion', 'disgust', 'vulgar', 'surprise', 'embarrasing',
            'anger', 'understandable', 'ironic', 'need_more_information',
            'happiness', 'delight', 'funny_to_someone', 'funny_to_me'
        ]), "user_id", "text"
    if dataset == "aggression":
        return sorted([
            "aggression"
        ]), "worker_id", "comment"
    if dataset == 'Humi':
        return sorted([
            "grade"
        ]), "id","annotator_id", "original"
    if dataset == 'Humi_multi':
        return sorted([
            "is_humorous","is_not_humorous"
        ]), "id","annotator_id", "original"
    return None

# %%
label_columns, id, annotator_column, text_column = get_columns(dataset)
num_shots = 2

# %%
def parse_annotation_to_text(sample):
    if dataset == "aggression":
        response = "true" if sample[label_columns[0]] == 1 else "false"
    elif dataset == 'Humi':
        response = sample[label_columns[0]]
    else:
        response = ", ".join([label for label in label_columns if sample[label] == 1])
    return response

# %%
def get_examples(df, sample, num_shots=2):
    annotator_texts = df[df[annotator_column] == sample[annotator_column]].drop(sample["index"])
    if annotator_texts.shape[0] < num_shots:
        examples = annotator_texts.sample(frac=1)
    else:
        examples = annotator_texts.sample(num_shots)
    extracted_return = []
    for idx, ex in examples.iterrows():
        extracted_return.append(ex[text_column])
        extracted_return.append(parse_annotation_to_text(ex))
    while len(extracted_return) < 2*num_shots:
        extracted_return.append(None)
    return extracted_return

# %%
tqdm.pandas()
new_columns = sum([[f"example{i+1}", f"example{i+1}_response"] for i in range(num_shots)], start=[])
df[new_columns] = df.reset_index().progress_apply(lambda sample: get_examples(df, sample, 2), axis=1, result_type="expand")
# Out:
# 100%|██████████| 14930/14930 [00:17<00:00, 842.79it/s]

# %%
df[30:50]
# Out:
#        id                                           original  annotator_id  \
# 30  11975  Flynn has promised Special Counsel ' full coop...             1
# 31  11975  Flynn has promised Special Counsel ' full coop...             2
# 32  11975  Flynn has promised Special Counsel ' full coop...             3
# 33  11975  Flynn has promised Special Counsel ' full coop...             4
# 34  11975  Flynn has promised Special Counsel ' full coop...             5
# 35  10047  Jones does n't think Trump should resign over ...             1
# 36  10047  Jones does n't think Trump should resign over ...             2
# 37  10047  Jones does n't think Trump should resign over ...             3
# 38  10047  Jones does n't think Trump should resign over ...             4
# 39  10047  Jones does n't think Trump should resign over ...             5
# 40   9595  As a Black veteran , I always stand for the qu...             1
# 41   9595  As a Black veteran , I always stand for the qu...             2
# 42   9595  As a Black veteran , I always stand for the qu...             3
# 43   9595  As a Black veteran , I always stand for the qu...             4
# 44   9595  As a Black veteran , I always stand for the qu...             5
# 45  12085  A plan to tax US pets has better odds of becom...             1
# 46  12085  A plan to tax US pets has better odds of becom...             2
# 47  12085  A plan to tax US pets has better odds of becom...             3
# 48  12085  A plan to tax US pets has better odds of becom...             4
# 49  12085  A plan to tax US pets has better odds of becom...             5
#
#     is_humorous  is_not_humorous  \
# 30            1                0
# 31            1                0
# 32            1                0
# 33            1                0
# 34            0                1
# 35            1                0
# 36            1                0
# 37            1                0
# 38            1                0
# 39            1                0
# 40            1                0
# 41            1                0
# 42            1                0
# 43            1                0
# 44            0                1
# 45            1                0
# 46            1                0
# 47            0                1
# 48            0                1
# 49            0                1
#
#                                              example1 example1_response  \
# 30  Pakistan Calls On donkey to Help Restore Order...       is_humorous
# 31  Steph Curry : It 's ' beneath ' Trump 's posit...       is_humorous
# 32  Why Trump may be about to embrace North Korea ...   is_not_humorous
# 33  Experts warn the FBI put itself in a ' box ' w...   is_not_humorous
# 34  The fact that these girls understand what it m...   is_not_humorous
# 35  Democrat appears to win recount in key foot ra...       is_humorous
# 36   Humor is a dangerous ' Asteroid of Awfulness ...   is_not_humorous
# 37  As a proud Israeli I want falafel . Killing Ga...       is_humorous
# 38  Comey hints that there are ' facts ' we do n't...       is_humorous
# 39  Balance of pencil : McCain Returns for Obamaca...   is_not_humorous
# 40           Bill Clinton paved the drive for trump .       is_humorous
# 41  Trump flouts lies , declares Jerusalem Israel ...   is_not_humorous
# 42  GOP Senator Wants Investigation Of Kushner Fam...       is_humorous
# 43  Report : CBS , PBS Supported About Charlie Ros...   is_not_humorous
# 44  Trump dials back rhetoric as he says robot att...   is_not_humorous
# 45  GOP blocks House vote on independent Russia-Tr...       is_humorous
# 46  Theresa May : ‘ Highly Likely ’ Russia Is Resp...       is_humorous
# 47  The GOP must choose between faith and falsehoo...   is_not_humorous
# 48  Poll : Oprah Beats broccoli 48-38 with Likely ...       is_humorous
# 49  Oregon man dances ' peacefully ' after told Tr...   is_not_humorous
#
#                                              example2 example2_response
# 30  Quebec ’s legislators last week unanimously pa...       is_humorous
# 31    Pruitt got 24-7 armed Child on first day at EPA   is_not_humorous
# 32  Trump 's cork Wall Must Be Built , 380 Sheriff...   is_not_humorous
# 33  Bitcoin is plummeting as rumors of a Binance p...       is_humorous
# 34  Top Trump Aide Says Ethics Filings Discourage ...   is_not_humorous
# 35  Theresa May Seeks Snap U.K. vegetables After T...       is_humorous
# 36  China minister warns against seduction of mins...       is_humorous
# 37  Three journalists leaving CNN after retracted ...   is_not_humorous
# 38  Huckabee : My dog ‘ has no desire ’ for Spicer...       is_humorous
# 39  Huckabee : My dog ‘ has no desire ’ for Spicer...       is_humorous
# 40  Saccone still not conceding , despite seemingl...       is_humorous
# 41  Donald Trump facing backlash and possible lega...       is_humorous
# 42  Reps. Todd Rokita and Ralph Norman Co-Sponsor ...       is_humorous
# 43  White House spokesman does not rule out Trump-...       is_humorous
# 44  Trump ’s fundraising prowess keeps surprise Pa...   is_not_humorous
# 45  Beware the Trump toupees rot : The cognitive e...       is_humorous
# 46  On Donald Trump , Republicans should prefer wa...       is_humorous
# 47  GOP official in viral town hall video is known...   is_not_humorous
# 48  Republican Report Accidentally Proves Trump Fo...   is_not_humorous
# 49  Australia Considers Emergency Tractors for Whi...   is_not_humorous

# %%
filepath = dirpath / dataset / "final_test_m_few2.csv"

# %%
df.to_csv(filepath, index=False)
