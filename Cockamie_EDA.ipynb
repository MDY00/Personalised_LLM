# %% [markdown]
# # Cockamie dataset eda

# %%
import pandas as pd
import json

# %%
with open("Data/Cockamie/cockamamie_gobbledegook_us_data.json", "r") as f: 
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['word_features', 'word_ratings'])

# %%
labels = data["word_features"]
" ".join(labels.keys())
# Out:
# 'snd scatc clq inslt juxt sexc'

# %%
workers = data["word_ratings"]["workers"]
print(workers)
# Out:
# [{'id': 0, 'age': 53, 'sex': 'Female'}, {'id': 1, 'age': 43, 'sex': 'Male'}, {'id': 2, 'age': 45, 'sex': 'Male'}, {'id': 3, 'age': 35, 'sex': 'Female'}, {'id': 4, 'age': 44, 'sex': 'Male'}, {'id': 5, 'age': 35, 'sex': 'Female'}, {'id': 6, 'age': 46, 'sex': 'Male'}, {'id': 7, 'age': 49, 'sex': 'Male'}, {'id': 8, 'age': 51, 'sex': 'Male'}, {'id': 9, 'age': 40, 'sex': 'Female'}, {'id': 10, 'age': 55, 'sex': 'Female'}, {'id': 11, 'age': 26, 'sex': 'Female'}, {'id': 12, 'age': 39, 'sex': 'Male'}, {'id': 13, 'age': 30, 'sex': 'Male'}, {'id': 14, 'age': 27, 'sex': 'Male'}, {'id': 15, 'age': 31, 'sex': 'Female'}, {'id': 16, 'age': 30, 'sex': 'Female'}, {'id': 17, 'age': 49, 'sex': 'Female'}, {'id': 18, 'age': 23, 'sex': 'Female'}, {'id': 19, 'age': 59, 'sex': 'Male'}, {'id': 20, 'age': 40, 'sex': 'Female'}, {'id': 21, 'age': 33, 'sex': 'Male'}, {'id': 22, 'age': 32, 'sex': 'Male'}, {'id': 23, 'age': 34, 'sex': 'Male'}, {'id': 24, 'age': 37, 'sex': 'Female'}, {'id': 25, 'age': 48, 'sex': 'Mal
# ...
